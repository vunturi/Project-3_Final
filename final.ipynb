# %%
from sklearn import tree
#import os 
import pandas as pd

#data = pd.read_csv('Multiple Cause of Death, 1999-2017.txt',sep=" " header = None)

#data.columns = ["Notes","Census Region","Census Region Code","State","State Code","Gender","Gender Code","Age Groups","TenYear Age Groups Code",\
                #"Year","Year Code"]
#df = pd.read_csv('death rate west verginia.csv')

#df_Death = pd.read_csv("Multiple_Cause_of_Death_WV_1999-2017_clean.csv")
df_Pharma =pd.read_csv("WVPharmData.csv")

# %%
#df_Pharma.to_string(columns = ["TRANSACTION_DATE"])
df_Pharma["transaction year"]= df_Pharma["TRANSACTION_DATE"].astype(str)
# slicing till 2nd last element 
#df_Pharma["transaction year"]= df_Pharma["transaction year"].str.slice(3, -1, 1) 
df_Pharma["transaction year"] = df_Pharma["transaction year"].apply(lambda x: x[-4:])

df_Pharma.rename(columns = {"BUYER_COUNTY":"County"}, inplace = True)
df_Pharma["County"]=df_Pharma["County"].astype(str)
#df_Pharma["County"].str.title()
df_Pharma["County"] =df_Pharma["County"].str.lower() 
df_Pharma.head()
# Out:
#                      BUYER_NAME  BUYER_CITY  BUYER_ZIP   County  DRUG_CODE  \
# 0  TRIVILLIAN'S PHAR OF KANAWHA  CHARLESTON      25304  kanawha       9193
# 1                   COLONY DRUG     BECKLEY      25801  raleigh       9193
# 2                   COLONY DRUG     BECKLEY      25801  raleigh       9193
# 3                   COLONY DRUG     BECKLEY      25801  raleigh       9193
# 4                   COLONY DRUG     BECKLEY      25801  raleigh       9193
#
#      DRUG_NAME  QUANTITY  DOSAGE_UNIT  TRANSACTION_DATE transaction year
# 0  HYDROCODONE       2.0       1000.0           6022006             2006
# 1  HYDROCODONE       1.0        500.0          11102011             2011
# 2  HYDROCODONE       1.0        500.0           3232012             2012
# 3  HYDROCODONE       1.0        500.0           5092012             2012
# 4  HYDROCODONE       1.0        500.0           6292012             2012

# %%
 df_Pharma.sort_values(by=['QUANTITY'])
# Out:
#                                   BUYER_NAME        BUYER_CITY  BUYER_ZIP  \
# 939659                       KROGER PHARMACY          BLUEWELL      24701
# 703530                                REED'S  BERKELEY SPRINGS      25411
# 703531                                REED'S  BERKELEY SPRINGS      25411
# 1378770   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 703533                                REED'S  BERKELEY SPRINGS      25411
# 703534                                REED'S  BERKELEY SPRINGS      25411
# 1378768   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 1378764   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 1378761   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 1378760   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 1378759   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 703541                                REED'S  BERKELEY SPRINGS      25411
# 703547                                REED'S  BERKELEY SPRINGS      25411
# 703529                                REED'S  BERKELEY SPRINGS      25411
# 1378750   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 1378749   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 703552                                REED'S  BERKELEY SPRINGS      25411
# 1378748  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 1378747  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 1378746  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 703556                                REED'S  BERKELEY SPRINGS      25411
# 1378744  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 1378742  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 1378741  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 703562                                REED'S  BERKELEY SPRINGS      25411
# 1378740  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 1378739  CHARLIE'S PHARMACY OF PINEVILLE LLC         PINEVILLE      24874
# 703550                                REED'S  BERKELEY SPRINGS      25411
# 1378771   CHARLIE'S PHARMACY OF MULLENS, LLC           MULLENS      25882
# 703527                                REED'S  BERKELEY SPRINGS      25411
# ...                                      ...               ...        ...
# 1010121         FAMILY DISCOUNT PHARMACY INC         MOUNT GAY      25637
# 142783                  BYPASS PHARMACY, INC           BECKLEY      25801
# 824323                  BYPASS PHARMACY, INC           BECKLEY      25801
# 1091119                 BYPASS PHARMACY, INC           BECKLEY      25801
# 528848                           COLONY DRUG           BECKLEY      25801
# 860797                           COLONY DRUG           BECKLEY      25801
# 1021447                          COLONY DRUG           BECKLEY      25801
# 975447           CHARLESTON MED CTR PHARMACY        CHARLESTON      25304
# 265796                           COLONY DRUG           BECKLEY      25801
# 904329                  BYPASS PHARMACY, INC           BECKLEY      25801
# 165309                  BYPASS PHARMACY, INC           BECKLEY      25801
# 1853060                 BYPASS PHARMACY, INC           BECKLEY      25801
# 1527238                          COLONY DRUG           BECKLEY      25801
# 55721                            COLONY DRUG           BECKLEY      25801
# 801708                  BYPASS PHARMACY, INC           BECKLEY      25801
# 1311267                 BYPASS PHARMACY, INC           BECKLEY      25801
# 1311264                 BYPASS PHARMACY, INC           BECKLEY      25801
# 1816297                 MOUNDSVILLE PHARMACY       MOUNDSVILLE      26041
# 1280114                BOND'S DRUG STORE INC        WASHINGTON      26181
# 140995                      MOORE'S PHARMACY       MARTINSBURG      25404
# 421414                           COLONY DRUG           BECKLEY      25801
# 1573137                          COLONY DRUG           BECKLEY      25801
# 163429                           COLONY DRUG           BECKLEY      25801
# 536593                  BYPASS PHARMACY, INC           BECKLEY      25801
# 264110                  BYPASS PHARMACY, INC           BECKLEY      25801
# 474324                  BYPASS PHARMACY, INC           BECKLEY      25801
# 1785102                 BYPASS PHARMACY, INC           BECKLEY      25801
# 123639                  BYPASS PHARMACY, INC           BECKLEY      25801
# 1062349                 BYPASS PHARMACY, INC           BECKLEY      25801
# 1721733          CHARLESTON MED CTR PHARMACY        CHARLESTON      25304
#
#            County  DRUG_CODE    DRUG_NAME  QUANTITY  DOSAGE_UNIT  \
# 939659     mercer       9193  HYDROCODONE       1.0        500.0
# 703530     morgan       9193  HYDROCODONE       1.0        100.0
# 703531     morgan       9193  HYDROCODONE       1.0        500.0
# 1378770   wyoming       9193  HYDROCODONE       1.0        100.0
# 703533     morgan       9143    OXYCODONE       1.0        100.0
# 703534     morgan       9193  HYDROCODONE       1.0        100.0
# 1378768   wyoming       9143    OXYCODONE       1.0        100.0
# 1378764   wyoming       9143    OXYCODONE       1.0        100.0
# 1378761   wyoming       9143    OXYCODONE       1.0        100.0
# 1378760   wyoming       9143    OXYCODONE       1.0        100.0
# 1378759   wyoming       9193  HYDROCODONE       1.0        500.0
# 703541     morgan       9193  HYDROCODONE       1.0        100.0
# 703547     morgan       9143    OXYCODONE       1.0        100.0
# 703529     morgan       9193  HYDROCODONE       1.0        500.0
# 1378750   wyoming       9193  HYDROCODONE       1.0        100.0
# 1378749   wyoming       9193  HYDROCODONE       1.0        100.0
# 703552     morgan       9143    OXYCODONE       1.0        100.0
# 1378748   wyoming       9143    OXYCODONE       1.0        100.0
# 1378747   wyoming       9193  HYDROCODONE       1.0        100.0
# 1378746   wyoming       9193  HYDROCODONE       1.0        500.0
# 703556     morgan       9193  HYDROCODONE       1.0        500.0
# 1378744   wyoming       9193  HYDROCODONE       1.0        500.0
# 1378742   wyoming       9193  HYDROCODONE       1.0        500.0
# 1378741   wyoming       9193  HYDROCODONE       1.0        500.0
# 703562     morgan       9143    OXYCODONE       1.0        100.0
# 1378740   wyoming       9193  HYDROCODONE       1.0        500.0
# 1378739   wyoming       9143    OXYCODONE       1.0        100.0
# 703550     morgan       9143    OXYCODONE       1.0        100.0
# 1378771   wyoming       9143    OXYCODONE       1.0        100.0
# 703527     morgan       9143    OXYCODONE       1.0        100.0
# ...           ...        ...          ...       ...          ...
# 1010121     logan       9143    OXYCODONE     112.0      11200.0
# 142783    raleigh       9143    OXYCODONE     120.0      12000.0
# 824323    raleigh       9143    OXYCODONE     120.0      12000.0
# 1091119   raleigh       9143    OXYCODONE     120.0      12000.0
# 528848    raleigh       9143    OXYCODONE     122.0      12200.0
# 860797    raleigh       9143    OXYCODONE     130.0      13000.0
# 1021447   raleigh       9143    OXYCODONE     132.0      13200.0
# 975447    kanawha       9143    OXYCODONE     144.0      14400.0
# 265796    raleigh       9143    OXYCODONE     144.0      14400.0
# 904329    raleigh       9143    OXYCODONE     144.0      14400.0
# 165309    raleigh       9143    OXYCODONE     144.0      14400.0
# 1853060   raleigh       9143    OXYCODONE     144.0      14400.0
# 1527238   raleigh       9143    OXYCODONE     144.0      14400.0
# 55721     raleigh       9143    OXYCODONE     144.0      14400.0
# 801708    raleigh       9143    OXYCODONE     144.0      14400.0
# 1311267   raleigh       9143    OXYCODONE     144.0      14400.0
# 1311264   raleigh       9143    OXYCODONE     144.0      14400.0
# 1816297  marshall       9143    OXYCODONE     150.0      15000.0
# 1280114      wood       9143    OXYCODONE     150.0      15000.0
# 140995   berkeley       9143    OXYCODONE     150.0      15000.0
# 421414    raleigh       9143    OXYCODONE     168.0      16800.0
# 1573137   raleigh       9143    OXYCODONE     168.0      16800.0
# 163429    raleigh       9143    OXYCODONE     168.0      16800.0
# 536593    raleigh       9143    OXYCODONE     170.0      17000.0
# 264110    raleigh       9143    OXYCODONE     170.0      17000.0
# 474324    raleigh       9143    OXYCODONE     170.0      17000.0
# 1785102   raleigh       9143    OXYCODONE     190.0      19000.0
# 123639    raleigh       9143    OXYCODONE     192.0      19200.0
# 1062349   raleigh       9143    OXYCODONE     192.0      19200.0
# 1721733   kanawha       9143    OXYCODONE     288.0      28800.0
#
#          TRANSACTION_DATE transaction year
# 939659            9232008             2008
# 703530            2172009             2009
# 703531            4072009             2009
# 1378770           9232009             2009
# 703533            9022009             2009
# 703534           12152009             2009
# 1378768           7282009             2009
# 1378764          11252008             2008
# 1378761           9192008             2008
# 1378760           9082008             2008
# 1378759           9222008             2008
# 703541           11172010             2010
# 703547            3182011             2011
# 703529            2262009             2009
# 1378750           3042008             2008
# 1378749           3242008             2008
# 703552            2062012             2012
# 1378748          10272011             2011
# 1378747          10112011             2011
# 1378746          10172011             2011
# 703556            4052012             2012
# 1378744           8122011             2011
# 1378742           6162011             2011
# 1378741           5312011             2011
# 703562           10282012             2012
# 1378740           4082011             2011
# 1378739           4052011             2011
# 703550           11162011             2011
# 1378771          11092009             2009
# 703527            2252009             2009
# ...                   ...              ...
# 1010121           6032009             2009
# 142783           12052011             2011
# 824323           12062011             2011
# 1091119           7052011             2011
# 528848            7142006             2006
# 860797            9222006             2006
# 1021447           8072006             2006
# 975447            7112007             2007
# 265796            8142007             2007
# 904329            9062012             2012
# 165309           10072012             2012
# 1853060           8062012             2012
# 1527238          11302007             2007
# 55721             2142007             2007
# 801708           11072012             2012
# 1311267          12092012             2012
# 1311264           4022012             2012
# 1816297           7012009             2009
# 1280114           8102006             2006
# 140995            9182006             2006
# 421414            3012007             2007
# 1573137          12212006             2006
# 163429            4302007             2007
# 536593            8062012             2012
# 264110           10072012             2012
# 474324            9062012             2012
# 1785102           7052012             2012
# 123639            5022012             2012
# 1062349           6042012             2012
# 1721733           7132006             2006
#
# [1879320 rows x 10 columns]

# %%
df_Pharma.QUANTITY.unique()
# Out:
# array([  2.,   1.,   4.,   6.,  24.,   3.,  20.,   8.,   5.,  18.,  12.,
#          9.,  10.,  15.,  13.,   7.,  11.,  14.,  60., 100.,  22.,  84.,
#         17.,  23.,  19.,  31.,  21.,  16.,  28.,  44.,  58.,  33.,  48.,
#         25.,  29.,  30.,  40.,  36.,  39.,  50.,  26.,  27.,  35., 144.,
#         37.,  55.,  78.,  38.,  80.,  32.,  68.,  96.,  65.,  53.,  45.,
#         46., 192.,  70.,  34.,  42., 150.,  54., 120.,  47.,  43., 168.,
#         75.,  72.,  79.,  49.,  41.,  81.,  98., 170.,  99.,  64.,  90.,
#         62.,  51., 122.,  57.,  66.,  67.,  56.,  59., 130.,  61., 112.,
#        132.,  63.,  86.,  83.,  52.,  74.,  77.,  87., 108., 288., 190.])

# %%
len(df_Pharma.County.unique())
# Out:
# 55

# %%
#target = df["Outcome"]
#target_names = ["negative", "positive"]
#df_Death["Year Code"]= df_Death["Year Code"].astype(str)
#df_Death["Year Code"]=df_Death["Year Code"].apply(lambda x: x[:4])
#df_Death["Deaths"]= df_Death["Deaths"].astype(str)
#df_Death["Deaths"]=df_Death["Deaths"].apply(lambda x: x[:2])
#df_Death["Population"]= df_Death["Population"].astype(str)
#df_Death["Population"]=df_Death["Population"].apply(lambda x: x[:4])
# df_Death["County"]=df_Death["County"].str.lower()
# df_Death.show()

# %%
dfNEW = pd.read_table('input3.txt')
dfNEW.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#   Notes              County  County Code    Year  Year Code  Deaths  \
# 0   NaN  Barbour County, WV      54001.0  2006.0     2006.0   201.0
# 1   NaN  Barbour County, WV      54001.0  2007.0     2007.0   164.0
# 2   NaN  Barbour County, WV      54001.0  2008.0     2008.0   179.0
# 3   NaN  Barbour County, WV      54001.0  2009.0     2009.0   188.0
# 4   NaN  Barbour County, WV      54001.0  2010.0     2010.0   174.0
#
#    Population  Crude Rate
# 0     15922.0      1262.4
# 1     16036.0      1022.7
# 2     16241.0      1102.1
# 3     16479.0      1140.8
# 4     16589.0      1048.9

# %%
dfCounties= dfNEW[['County', 'Year', 'Population', 'Deaths']]
dfCounties.head()
# Out:
#                County    Year  Population  Deaths
# 0  Barbour County, WV  2006.0     15922.0   201.0
# 1  Barbour County, WV  2007.0     16036.0   164.0
# 2  Barbour County, WV  2008.0     16241.0   179.0
# 3  Barbour County, WV  2009.0     16479.0   188.0
# 4  Barbour County, WV  2010.0     16589.0   174.0

# %%
dfCounties['county']=dfCounties['County'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfCounties['county_new'] = dfCounties['county'].str.split(' ').str[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfCounties["countyF"] =dfCounties["county_new"].str.lower()
dfCounties.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                County    Year  Population  Deaths              county  \
# 0  Barbour County, WV  2006.0     15922.0   201.0  Barbour County, WV
# 1  Barbour County, WV  2007.0     16036.0   164.0  Barbour County, WV
# 2  Barbour County, WV  2008.0     16241.0   179.0  Barbour County, WV
# 3  Barbour County, WV  2009.0     16479.0   188.0  Barbour County, WV
# 4  Barbour County, WV  2010.0     16589.0   174.0  Barbour County, WV
#
#   county_new  countyF
# 0    Barbour  barbour
# 1    Barbour  barbour
# 2    Barbour  barbour
# 3    Barbour  barbour
# 4    Barbour  barbour

# %%
dfCounties=dfCounties.dropna()

# %%
len(dfCounties)
# Out:
# 385

# %%
dfCounties=dfCounties[['countyF', 'Year', 'Population', 'Deaths']]
dfCounties.rename(columns = {"countyF":"County"}, inplace = True)
dfCounties.head()
# Out:
#     County    Year  Population  Deaths
# 0  barbour  2006.0     15922.0   201.0
# 1  barbour  2007.0     16036.0   164.0
# 2  barbour  2008.0     16241.0   179.0
# 3  barbour  2009.0     16479.0   188.0
# 4  barbour  2010.0     16589.0   174.0

# %%
dfCounties['New_Year']=dfCounties['Year'].astype(str)
dfCounties.head()
# Out:
#     County    Year  Population  Deaths New_Year
# 0  barbour  2006.0     15922.0   201.0   2006.0
# 1  barbour  2007.0     16036.0   164.0   2007.0
# 2  barbour  2008.0     16241.0   179.0   2008.0
# 3  barbour  2009.0     16479.0   188.0   2009.0
# 4  barbour  2010.0     16589.0   174.0   2010.0

# %%
dfCounties['Year_new'] = dfCounties['New_Year'].str.split('.').str[0]
dfCounties.head()
# Out:
#     County    Year  Population  Deaths New_Year Year_new
# 0  barbour  2006.0     15922.0   201.0   2006.0     2006
# 1  barbour  2007.0     16036.0   164.0   2007.0     2007
# 2  barbour  2008.0     16241.0   179.0   2008.0     2008
# 3  barbour  2009.0     16479.0   188.0   2009.0     2009
# 4  barbour  2010.0     16589.0   174.0   2010.0     2010

# %%
dfCounties=dfCounties[['County', 'Year_new', 'Population', 'Deaths']]
dfCounties.rename(columns = {"Year_new":"Year"}, inplace = True)
dfCounties.head()
# Out:
#     County  Year  Population  Deaths
# 0  barbour  2006     15922.0   201.0
# 1  barbour  2007     16036.0   164.0
# 2  barbour  2008     16241.0   179.0
# 3  barbour  2009     16479.0   188.0
# 4  barbour  2010     16589.0   174.0

# %%
print(len(df_Pharma))
# Out:
# 1879320

# %%
merge_table = pd.merge(df_Pharma, dfCounties, how='left', left_on=['County','transaction year'], right_on = ['County','Year'])
merge_table

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
D=merge_table["Population"].values
kmeans.fit(D.reshape(-1,1))

# starting from here we need to figure out the machine learning model
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
D=merge_table["Population"].values

# %%
D.reshape(-1,1)
# Out:
# array([[192954.],
#        [ 79127.],
#        [ 79021.],
#        ...,
#        [ 54504.],
#        [ 54504.],
#        [ 54504.]])

# %%
predicted_clusters = KMeans.predict(D)
X = D["Population"]
Y = D["Deaths"]
feature_names = D.columns
predicted_clusters = KMeans.predict(D)
#D.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-8c0ee1f13dc6> in <module>
#       1
# ----> 2 predicted_clusters = KMeans.predict(D)
#       3 X = D["Population"]
#       4 Y = D["Deaths"]
#       5 feature_names = D.columns
#
# TypeError: predict() missing 1 required positional argument: 'X'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.671875

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.72916666666666663

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.2604038892633122, 'Glucose'),
#  (0.16240738779159666, 'BMI'),
#  (0.1437077712983523, 'Age'),
#  (0.12126276641273467, 'DiabetesPedigreeFunction'),
#  (0.088871399128041817, 'BloodPressure'),
#  (0.079222898914976206, 'Pregnancies'),
#  (0.07440650942444979, 'Insulin'),
#  (0.069717377766536262, 'SkinThickness')]

# %%
dfWVTOT = pd.read_table('ALLDEATHSWV.txt')
dfWVTOT.head()
# Out:
#   Notes    Year  Year Code   Deaths  Population  Crude Rate
# 0   NaN  2006.0     2006.0  20672.0   1827912.0      1130.9
# 1   NaN  2007.0     2007.0  21086.0   1834052.0      1149.7
# 2   NaN  2008.0     2008.0  21557.0   1840310.0      1171.4
# 3   NaN  2009.0     2009.0  21386.0   1847775.0      1157.4
# 4   NaN  2010.0     2010.0  21275.0   1852994.0      1148.1

# %%
dfWVTot= dfWVTOT [['Year', 'Deaths', 'Population']]
len(dfWVTot)
# Out:
# 48

# %%
dfWVTot=dfWVTot.dropna()

# %%
dfWVTot.head()
# Out:
#      Year   Deaths  Population
# 0  2006.0  20672.0   1827912.0
# 1  2007.0  21086.0   1834052.0
# 2  2008.0  21557.0   1840310.0
# 3  2009.0  21386.0   1847775.0
# 4  2010.0  21275.0   1852994.0

# %%
dfWVDrug = pd.read_table('DRUGDEATHSWV.txt')
dfWVDrug.head()
# Out:
#   Notes    Year  Year Code  Deaths  Population  Crude Rate
# 0   NaN  2006.0     2006.0   378.0   1827912.0        20.7
# 1   NaN  2007.0     2007.0   405.0   1834052.0        22.1
# 2   NaN  2008.0     2008.0   468.0   1840310.0        25.4
# 3   NaN  2009.0     2009.0   235.0   1847775.0        12.7
# 4   NaN  2010.0     2010.0   520.0   1852994.0        28.1

# %%
dfWVDrug= dfWVDrug [['Year', 'Deaths', 'Population']]

# %%
dfWVDrug = dfWVDrug.dropna()

# %%
len(dfWVDrug)
# Out:
# 7

# %%
dfWVDrug.rename(columns = {"Deaths":"Drug_Deaths"}, inplace = True)

# %%
dfWVDrug.head()
# Out:
#      Year  Drug_Deaths  Population
# 0  2006.0        378.0   1827912.0
# 1  2007.0        405.0   1834052.0
# 2  2008.0        468.0   1840310.0
# 3  2009.0        235.0   1847775.0
# 4  2010.0        520.0   1852994.0

# %%
Totals_Merged= pd.merge(dfWVDrug,dfWVTot , on="Year")

# %%
Totals_Merged
# Out:
#      Year  Drug_Deaths  Population_x   Deaths  Population_y
# 0  2006.0        378.0     1827912.0  20672.0     1827912.0
# 1  2007.0        405.0     1834052.0  21086.0     1834052.0
# 2  2008.0        468.0     1840310.0  21557.0     1840310.0
# 3  2009.0        235.0     1847775.0  21386.0     1847775.0
# 4  2010.0        520.0     1852994.0  21275.0     1852994.0
# 5  2011.0        645.0     1855364.0  21867.0     1855364.0
# 6  2012.0        576.0     1855413.0  21915.0     1855413.0

# %%
Totals_Merged=Totals_Merged.drop('Population_x', axis=1)

# %%
Totals_Merged.rename(columns = {"Population_y":"Population"}, inplace = True)

# %%
Totals_Merged
# Out:
#      Year  Drug_Deaths   Deaths  Population
# 0  2006.0        378.0  20672.0   1827912.0
# 1  2007.0        405.0  21086.0   1834052.0
# 2  2008.0        468.0  21557.0   1840310.0
# 3  2009.0        235.0  21386.0   1847775.0
# 4  2010.0        520.0  21275.0   1852994.0
# 5  2011.0        645.0  21867.0   1855364.0
# 6  2012.0        576.0  21915.0   1855413.0
